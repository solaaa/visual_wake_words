# %%
import numpy as np
import PIL
import matplotlib.pyplot as p
import input_data

# %%
im_process = input_data.DataProcessor(r'E:\Visual Wake Words\data\coco_dataset', 1, '100 100')

# %%
g = im_process.train_data_generator()

# %%
data, label = next(g)
data = data.reshape([100,100])
p.figure(1)
p.imshow(data)
print(label)
# Out:
# [1]

# %%
data =
# Out:
# (1, 100, 100, 1)
