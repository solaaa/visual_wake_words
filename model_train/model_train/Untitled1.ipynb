# %%
import numpy as np
import PIL
import matplotlib.pyplot as p
import input_data

# %%
im_process = input_data.DataProcessor(r'E:\Visual Wake Words\data\coco_dataset', 10, '192 192')

# %%
g = im_process.val_data_generator()

# %%
data, label = next(g)
label
# Out:
# array([0, 0, 1, 1, 0, 1, 1, 1, 0, 1])

# %%
for i in range(10):
    p.figure(i)
    p.imshow(data[i].reshape([192,192]))
    print(label[i])
# Out:
# 0
# 0
# 1
# 1
# 0
# 1
# 1
# 1
# 0
# 1

# %%
[100 for _ in range(5)]
# Out:
# [100, 100, 100, 100, 100]

# %%
start = 0.02
decay = 0.94
epoch = 100
# l = [start]*epoch
l = [start*(decay**i) for i in range(0, epoch)]
l
# Out:
# [0.02,
#  0.0188,
#  0.017672,
#  0.016611679999999997,
#  0.015614979199999997,
#  0.014678080447999994,
#  0.013797395621119994,
#  0.012969551883852794,
#  0.012191378770821626,
#  0.011459896044572329,
#  0.010772302281897987,
#  0.010125964144984108,
#  0.00951840629628506,
#  0.008947301918507957,
#  0.008410463803397479,
#  0.00790583597519363,
#  0.007431485816682012,
#  0.006985596667681091,
#  0.006566460867620225,
#  0.006172473215563011,
#  0.00580212482262923,
#  0.005453997333271475,
#  0.005126757493275187,
#  0.004819152043678675,
#  0.004530002921057955,
#  0.004258202745794477,
#  0.004002710581046808,
#  0.0037625479461839994,
#  0.00353679506941296,
#  0.003324587365248182,
#  0.003125112123333291,
#  0.0029376053959332933,
#  0.0027613490721772956,
#  0.0025956681278466575,
#  0.002439928040175858,
#  0.0022935323577653066,
#  0.0021559204162993877,
#  0.0020265651913214246,
#  0.0019049712798421387,
#  0.0017906730030516102,
#  0.0016832326228685135,
# ...
